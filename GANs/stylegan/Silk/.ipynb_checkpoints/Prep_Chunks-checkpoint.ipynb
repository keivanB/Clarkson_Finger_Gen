# %%
import os

import sys
'''PATH to lpips library for perceptual loss'''
new_path = '/home/cc/stylegan_K1/'
sys.path.append(new_path)

import glob
import argparse
import threading
import six.moves.queue as Queue # pylint: disable=import-error
import traceback
import numpy as np
import tensorflow as tf
import PIL.Image
import dnnlib.tflib as tflib

from training import dataset
import pandas as pd
import shutil as sh
import matplotlib.pyplot as plt

from skimage.transform import resize
from skimage import io
# Out:
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
class TFRecordExporter:
    def __init__(self, tfrecord_dir, expected_images, print_progress=True, progress_interval=10):
        self.tfrecord_dir       = tfrecord_dir
        self.tfr_prefix         = os.path.join(self.tfrecord_dir, os.path.basename(self.tfrecord_dir))
        self.expected_images    = expected_images
        self.cur_images         = 0
        self.shape              = None
        self.resolution_log2    = None
        self.tfr_writers        = []
        self.print_progress     = print_progress
        self.progress_interval  = progress_interval

        if self.print_progress:
            print('Creating dataset "%s"' % tfrecord_dir)
        if not os.path.isdir(self.tfrecord_dir):
            os.makedirs(self.tfrecord_dir)
        assert os.path.isdir(self.tfrecord_dir)

    def close(self):
        if self.print_progress:
            print('%-40s\r' % 'Flushing data...', end='', flush=True)
        for tfr_writer in self.tfr_writers:
            tfr_writer.close()
        self.tfr_writers = []
        if self.print_progress:
            print('%-40s\r' % '', end='', flush=True)
            print('Added %d images.' % self.cur_images)

    def choose_shuffled_order(self): # Note: Images and labels must be added in shuffled order.
        order = np.arange(self.expected_images)
        np.random.RandomState(123).shuffle(order)
        return order

    def add_image(self, img):
        if self.print_progress and self.cur_images % self.progress_interval == 0:
            print('%d / %d\r' % (self.cur_images, self.expected_images), end='', flush=True)
        if self.shape is None:
            self.shape = img.shape
            self.resolution_log2 = int(np.log2(self.shape[1]))
            assert self.shape[0] in [1, 3]
            assert self.shape[1] == self.shape[2]
            assert self.shape[1] == 2**self.resolution_log2
            tfr_opt = tf.python_io.TFRecordOptions(tf.python_io.TFRecordCompressionType.NONE)
            for lod in range(self.resolution_log2 - 1):
                tfr_file = self.tfr_prefix + '-r%02d.tfrecords' % (self.resolution_log2 - lod)
                self.tfr_writers.append(tf.python_io.TFRecordWriter(tfr_file, tfr_opt))
        assert img.shape == self.shape
        for lod, tfr_writer in enumerate(self.tfr_writers):
            if lod:
                img = img.astype(np.float32)
                img = (img[:, 0::2, 0::2] + img[:, 0::2, 1::2] + img[:, 1::2, 0::2] + img[:, 1::2, 1::2]) * 0.25
            quant = np.rint(img).clip(0, 255).astype(np.uint8)
            ex = tf.train.Example(features=tf.train.Features(feature={
                'shape': tf.train.Feature(int64_list=tf.train.Int64List(value=quant.shape)),
                'data': tf.train.Feature(bytes_list=tf.train.BytesList(value=[quant.tostring()]))}))
            tfr_writer.write(ex.SerializeToString())
        self.cur_images += 1

    def add_labels(self, labels):
        if self.print_progress:
            print('%-40s\r' % 'Saving labels...', end='', flush=True)
        assert labels.shape[0] == self.cur_images
        with open(self.tfr_prefix + '-rxx.labels', 'wb') as f:
            np.save(f, labels.astype(np.float32))

    def __enter__(self):
        return self

    def __exit__(self, *args):
        self.close()

# %%
data_pd = pd.read_pickle('/home/cc/Data/Zips/silk_index_df_fixed.p')

# %%
data_pd
# Out:
#         CaptureID  Attempt CaptureID.1  \
# 0           ds1_1      NaN       ds1_1
# 1           ds1_2      NaN       ds1_2
# 2           ds1_3      NaN       ds1_3
# 3           ds1_4      NaN       ds1_4
# 4           ds1_5      NaN       ds1_5
# 5           ds1_6      NaN       ds1_6
# 6           ds1_7      NaN       ds1_7
# 7           ds1_8      NaN       ds1_8
# 8          ds1_10      NaN      ds1_10
# 9          ds1_11      NaN      ds1_11
# 10         ds1_12      NaN      ds1_12
# 11         ds1_13      NaN      ds1_13
# 12         ds1_14      NaN      ds1_14
# 13         ds1_15      NaN      ds1_15
# 14         ds1_16      NaN      ds1_16
# 15         ds1_17      NaN      ds1_17
# 16         ds1_18      NaN      ds1_18
# 17         ds1_21      NaN      ds1_21
# 18         ds1_22      NaN      ds1_22
# 19         ds1_23      NaN      ds1_23
# 20         ds1_24      NaN      ds1_24
# 21         ds1_25      NaN      ds1_25
# 22         ds1_26      NaN      ds1_26
# 23         ds1_27      NaN      ds1_27
# 24         ds1_28      NaN      ds1_28
# 25         ds1_29      NaN      ds1_29
# 26         ds1_30      NaN      ds1_30
# 27         ds1_31      NaN      ds1_31
# 28         ds1_32      NaN      ds1_32
# 29         ds1_33      NaN      ds1_33
# ...           ...      ...         ...
# 103666  gs3_13999      NaN   gs3_13999
# 103667  gs3_14000      NaN   gs3_14000
# 103668  gs3_14001      NaN   gs3_14001
# 103669  gs3_14002      NaN   gs3_14002
# 103670  gs3_14003      NaN   gs3_14003
# 103671  gs3_14004      NaN   gs3_14004
# 103672  gs3_14005      NaN   gs3_14005
# 103673  gs3_14006      NaN   gs3_14006
# 103674  gs3_14007      NaN   gs3_14007
# 103675  gs3_14008      NaN   gs3_14008
# 103676  gs3_14009      NaN   gs3_14009
# 103677  gs3_14010      NaN   gs3_14010
# 103678  gs3_14011      NaN   gs3_14011
# 103679  gs3_14012      NaN   gs3_14012
# 103680  gs3_14013      NaN   gs3_14013
# 103681  gs3_14014      NaN   gs3_14014
# 103682  gs3_14015      NaN   gs3_14015
# 103683  gs3_14016      NaN   gs3_14016
# 103684  gs3_14017      NaN   gs3_14017
# 103685  gs3_14018      NaN   gs3_14018
# 103686  gs3_14019      NaN   gs3_14019
# 103687  gs3_14020      NaN   gs3_14020
# 103688  gs3_14021      NaN   gs3_14021
# 103689  gs3_14022      NaN   gs3_14022
# 103690  gs3_14023      NaN   gs3_14023
# 103691  gs3_14024      NaN   gs3_14024
# 103692  gs3_14025      NaN   gs3_14025
# 103693  gs3_14026      NaN   gs3_14026
# 103694  gs3_14027      NaN   gs3_14027
# 103695  gs3_14028      NaN   gs3_14028
#
#                                                  FilePath        Finger  \
# 0       dev_set_1/Static_images/live/3932164900003/200...   Left Little
# 1       dev_set_1/Static_images/live/3932164900003/200...   Left Little
# 2       dev_set_1/Static_images/live/3932164900003/200...  Right Little
# 3       dev_set_1/Static_images/live/3932164900003/200...  Right Little
# 4       dev_set_1/Static_images/live/3932164900003/200...     Left Ring
# 5       dev_set_1/Static_images/live/3932164900003/200...     Left Ring
# 6       dev_set_1/Static_images/live/3932164900003/200...   Left Middle
# 7       dev_set_1/Static_images/live/3932164900003/200...    Left Index
# 8       dev_set_1/Static_images/live/3932164900003/200...    Left Thumb
# 9       dev_set_1/Static_images/live/3932164900003/200...    Left Thumb
# 10      dev_set_1/Static_images/live/3932164900003/200...   Right Thumb
# 11      dev_set_1/Static_images/live/3932164900003/200...   Right Thumb
# 12      dev_set_1/Static_images/live/3932164900003/200...   Right Index
# 13      dev_set_1/Static_images/live/3932164900003/200...   Right Index
# 14      dev_set_1/Static_images/live/3932164900003/200...  Right Middle
# 15      dev_set_1/Static_images/live/3932164900003/200...  Right Middle
# 16      dev_set_1/Static_images/live/3932164900003/200...    Right Ring
# 17      dev_set_1/Static_images/live/3932164900003/200...   Left Little
# 18      dev_set_1/Static_images/live/3932164900003/200...   Left Little
# 19      dev_set_1/Static_images/live/3932164900003/200...  Right Little
# 20      dev_set_1/Static_images/live/3932164900003/200...  Right Little
# 21      dev_set_1/Static_images/live/3932164900003/200...     Left Ring
# 22      dev_set_1/Static_images/live/3932164900003/200...     Left Ring
# 23      dev_set_1/Static_images/live/3932164900003/200...   Left Middle
# 24      dev_set_1/Static_images/live/3932164900003/200...   Left Middle
# 25      dev_set_1/Static_images/live/3932164900003/200...    Left Index
# 26      dev_set_1/Static_images/live/3932164900003/200...    Left Index
# 27      dev_set_1/Static_images/live/3932164900003/200...    Left Thumb
# 28      dev_set_1/Static_images/live/3932164900003/200...    Left Thumb
# 29      dev_set_1/Static_images/live/3932164900003/200...   Right Thumb
# ...                                                   ...           ...
# 103666  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...             1
# 103667  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...             2
# 103668  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...             3
# 103669  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...             4
# 103670  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...             5
# 103671  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...             6
# 103672  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...             7
# 103673  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...             8
# 103674  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...             9
# 103675  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...            10
# 103676  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             1
# 103677  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             2
# 103678  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             3
# 103679  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             4
# 103680  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             5
# 103681  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             6
# 103682  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             7
# 103683  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             8
# 103684  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             9
# 103685  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...            10
# 103686  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             1
# 103687  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             2
# 103688  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             3
# 103689  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             4
# 103690  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             5
# 103691  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             6
# 103692  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             7
# 103693  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             8
# 103694  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...             9
# 103695  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...            10
#
#                                                FingerType  \
# 0                                                    LIVE
# 1                                                    LIVE
# 2                                                    LIVE
# 3                                                    LIVE
# 4                                                    LIVE
# 5                                                    LIVE
# 6                                                    LIVE
# 7                                                    LIVE
# 8                                                    LIVE
# 9                                                    LIVE
# 10                                                   LIVE
# 11                                                   LIVE
# 12                                                   LIVE
# 13                                                   LIVE
# 14                                                   LIVE
# 15                                                   LIVE
# 16                                                   LIVE
# 17                                                   LIVE
# 18                                                   LIVE
# 19                                                   LIVE
# 20                                                   LIVE
# 21                                                   LIVE
# 22                                                   LIVE
# 23                                                   LIVE
# 24                                                   LIVE
# 25                                                   LIVE
# 26                                                   LIVE
# 27                                                   LIVE
# 28                                                   LIVE
# 29                                                   LIVE
# ...                                                   ...
# 103666                                               Live
# 103667                                               Live
# 103668                                               Live
# 103669  Gummy Fingerprint Overlay, Ecoflex 00-50 with ...
# 103670                                               Live
# 103671                                               Live
# 103672                                               Live
# 103673                                               Live
# 103674                                               Live
# 103675                                               Live
# 103676                                               Live
# 103677                                               Live
# 103678  Gummy overlay, VeroBlackPlus mold/Gelatin Cast...
# 103679                                               Live
# 103680                                               Live
# 103681                                               Live
# 103682                                               Live
# 103683                                               Live
# 103684                                               Live
# 103685                                               Live
# 103686                                               Live
# 103687                                               Live
# 103688  Gummy overlay, VeroBlackPlus mold/Gelatin Cast...
# 103689                                               Live
# 103690                                               Live
# 103691                                               Live
# 103692                                               Live
# 103693                                               Live
# 103694                                               Live
# 103695                                               Live
#
#                                                    PathF1  \
# 0       dev_set_1/Sequences/live/3932164900003/2000020...
# 1       dev_set_1/Sequences/live/3932164900003/2000020...
# 2       dev_set_1/Sequences/live/3932164900003/2000020...
# 3       dev_set_1/Sequences/live/3932164900003/2000020...
# 4       dev_set_1/Sequences/live/3932164900003/2000020...
# 5       dev_set_1/Sequences/live/3932164900003/2000020...
# 6       dev_set_1/Sequences/live/3932164900003/2000020...
# 7       dev_set_1/Sequences/live/3932164900003/2000020...
# 8       dev_set_1/Sequences/live/3932164900003/2000020...
# 9       dev_set_1/Sequences/live/3932164900003/2000020...
# 10      dev_set_1/Sequences/live/3932164900003/2000020...
# 11      dev_set_1/Sequences/live/3932164900003/2000020...
# 12      dev_set_1/Sequences/live/3932164900003/2000020...
# 13      dev_set_1/Sequences/live/3932164900003/2000020...
# 14      dev_set_1/Sequences/live/3932164900003/2000020...
# 15      dev_set_1/Sequences/live/3932164900003/2000020...
# 16      dev_set_1/Sequences/live/3932164900003/2000020...
# 17      dev_set_1/Sequences/live/3932164900003/2000391...
# 18      dev_set_1/Sequences/live/3932164900003/2000391...
# 19      dev_set_1/Sequences/live/3932164900003/2000391...
# 20      dev_set_1/Sequences/live/3932164900003/2000391...
# 21      dev_set_1/Sequences/live/3932164900003/2000391...
# 22      dev_set_1/Sequences/live/3932164900003/2000391...
# 23      dev_set_1/Sequences/live/3932164900003/2000391...
# 24      dev_set_1/Sequences/live/3932164900003/2000391...
# 25      dev_set_1/Sequences/live/3932164900003/2000391...
# 26      dev_set_1/Sequences/live/3932164900003/2000391...
# 27      dev_set_1/Sequences/live/3932164900003/2000391...
# 28      dev_set_1/Sequences/live/3932164900003/2000391...
# 29      dev_set_1/Sequences/live/3932164900003/2000391...
# ...                                                   ...
# 103666  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103667  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103668  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103669  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103670  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103671  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103672  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103673  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103674  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103675  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103676  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103677  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103678  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103679  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103680  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103681  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103682  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103683  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103684  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103685  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103686  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103687  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103688  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103689  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103690  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103691  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103692  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103693  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103694  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103695  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
#
#                                                   PathF10  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 103666  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103667  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103668  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103669  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103670  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103671  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103672  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103673  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103674  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103675  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103676  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103677  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103678  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103679  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103680  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103681  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103682  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103683  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103684  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103685  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103686  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103687  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103688  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103689  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103690  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103691  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103692  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103693  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103694  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103695  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
#
#                                                    PathF2  \
# 0       dev_set_1/Sequences/live/3932164900003/2000020...
# 1       dev_set_1/Sequences/live/3932164900003/2000020...
# 2       dev_set_1/Sequences/live/3932164900003/2000020...
# 3       dev_set_1/Sequences/live/3932164900003/2000020...
# 4       dev_set_1/Sequences/live/3932164900003/2000020...
# 5       dev_set_1/Sequences/live/3932164900003/2000020...
# 6       dev_set_1/Sequences/live/3932164900003/2000020...
# 7       dev_set_1/Sequences/live/3932164900003/2000020...
# 8       dev_set_1/Sequences/live/3932164900003/2000020...
# 9       dev_set_1/Sequences/live/3932164900003/2000020...
# 10      dev_set_1/Sequences/live/3932164900003/2000020...
# 11      dev_set_1/Sequences/live/3932164900003/2000020...
# 12      dev_set_1/Sequences/live/3932164900003/2000020...
# 13      dev_set_1/Sequences/live/3932164900003/2000020...
# 14      dev_set_1/Sequences/live/3932164900003/2000020...
# 15      dev_set_1/Sequences/live/3932164900003/2000020...
# 16      dev_set_1/Sequences/live/3932164900003/2000020...
# 17      dev_set_1/Sequences/live/3932164900003/2000391...
# 18      dev_set_1/Sequences/live/3932164900003/2000391...
# 19      dev_set_1/Sequences/live/3932164900003/2000391...
# 20      dev_set_1/Sequences/live/3932164900003/2000391...
# 21      dev_set_1/Sequences/live/3932164900003/2000391...
# 22      dev_set_1/Sequences/live/3932164900003/2000391...
# 23      dev_set_1/Sequences/live/3932164900003/2000391...
# 24      dev_set_1/Sequences/live/3932164900003/2000391...
# 25      dev_set_1/Sequences/live/3932164900003/2000391...
# 26      dev_set_1/Sequences/live/3932164900003/2000391...
# 27      dev_set_1/Sequences/live/3932164900003/2000391...
# 28      dev_set_1/Sequences/live/3932164900003/2000391...
# 29      dev_set_1/Sequences/live/3932164900003/2000391...
# ...                                                   ...
# 103666  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103667  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103668  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103669  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103670  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103671  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103672  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103673  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103674  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103675  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...
# 103676  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103677  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103678  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103679  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103680  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103681  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103682  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103683  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103684  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103685  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103686  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103687  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103688  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103689  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103690  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103691  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103692  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103693  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103694  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
# 103695  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...
#
#                                                    PathF3  ...  \
# 0       dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 1       dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 2       dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 3       dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 4       dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 5       dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 6       dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 7       dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 8       dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 9       dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 10      dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 11      dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 12      dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 13      dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 14      dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 15      dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 16      dev_set_1/Sequences/live/3932164900003/2000020...  ...
# 17      dev_set_1/Sequences/live/3932164900003/2000391...  ...
# 18      dev_set_1/Sequences/live/3932164900003/2000391...  ...
# 19      dev_set_1/Sequences/live/3932164900003/2000391...  ...
# 20      dev_set_1/Sequences/live/3932164900003/2000391...  ...
# 21      dev_set_1/Sequences/live/3932164900003/2000391...  ...
# 22      dev_set_1/Sequences/live/3932164900003/2000391...  ...
# 23      dev_set_1/Sequences/live/3932164900003/2000391...  ...
# 24      dev_set_1/Sequences/live/3932164900003/2000391...  ...
# 25      dev_set_1/Sequences/live/3932164900003/2000391...  ...
# 26      dev_set_1/Sequences/live/3932164900003/2000391...  ...
# 27      dev_set_1/Sequences/live/3932164900003/2000391...  ...
# 28      dev_set_1/Sequences/live/3932164900003/2000391...  ...
# 29      dev_set_1/Sequences/live/3932164900003/2000391...  ...
# ...                                                   ...  ...
# 103666  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...  ...
# 103667  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...  ...
# 103668  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...  ...
# 103669  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...  ...
# 103670  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...  ...
# 103671  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...  ...
# 103672  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...  ...
# 103673  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...  ...
# 103674  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...  ...
# 103675  gov_set_3/SilkIDFFR/SilkIDFFR_624a99d9e272511e...  ...
# 103676  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103677  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103678  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103679  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103680  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103681  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103682  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103683  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103684  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103685  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103686  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103687  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103688  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103689  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103690  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103691  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103692  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103693  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103694  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
# 103695  gov_set_3/SilkIDFFR/SilkIDFFR_a89699991ab0e6ad...  ...
#
#        set_type_fold_0 set_type_fold_1 set_type_fold_2 set_type_fold_3  \
# 0                   te              tr              tr              tr
# 1                   te              tr              tr              tr
# 2                   te              tr              tr              tr
# 3                   te              tr              tr              tr
# 4                   te              tr              tr              tr
# 5                   te              tr              tr              tr
# 6                   te              tr              tr              tr
# 7                   te              tr              tr              tr
# 8                   te              tr              tr              tr
# 9                   te              tr              tr              tr
# 10                  te              tr              tr              tr
# 11                  te              tr              tr              tr
# 12                  te              tr              tr              tr
# 13                  te              tr              tr              tr
# 14                  te              tr              tr              tr
# 15                  te              tr              tr              tr
# 16                  te              tr              tr              tr
# 17                  te               v              tr              tr
# 18                  te               v              tr              tr
# 19                  te               v              tr              tr
# 20                  te               v              tr              tr
# 21                  te               v              tr              tr
# 22                  te               v              tr              tr
# 23                  te               v              tr              tr
# 24                  te               v              tr              tr
# 25                  te               v              tr              tr
# 26                  te               v              tr              tr
# 27                  te               v              tr              tr
# 28                  te               v              tr              tr
# 29                  te               v              tr              tr
# ...                ...             ...             ...             ...
# 103666              tr               v              tr              tr
# 103667              tr               v              tr              tr
# 103668              tr               v              tr              tr
# 103669              tr               v              tr              tr
# 103670              tr               v              tr              tr
# 103671              tr               v              tr              tr
# 103672              tr               v              tr              tr
# 103673              tr               v              tr              tr
# 103674              tr               v              tr              tr
# 103675              tr               v              tr              tr
# 103676              tr              tr              tr              tr
# 103677              tr              tr              tr              tr
# 103678              tr              tr              tr              tr
# 103679              tr              tr              tr              tr
# 103680              tr              tr              tr              tr
# 103681              tr              tr              tr              tr
# 103682              tr              tr              tr              tr
# 103683              tr              tr              tr              tr
# 103684              tr              tr              tr              tr
# 103685              tr              tr              tr              tr
# 103686              tr              tr              tr              tr
# 103687              tr              tr              tr              tr
# 103688              tr              tr              tr              tr
# 103689              tr              tr              tr              tr
# 103690              tr              tr              tr              tr
# 103691              tr              tr              tr              tr
# 103692              tr              tr              tr              tr
# 103693              tr              tr              tr              tr
# 103694              tr              tr              tr              tr
# 103695              tr              tr              tr              tr
#
#        set_type_fold_4 set_type_fold_5  set_type_fold_6 set_type_fold_7  \
# 0                   tr              tr               tr               v
# 1                   tr              tr               tr               v
# 2                   tr              tr               tr               v
# 3                   tr              tr               tr               v
# 4                   tr              tr               tr               v
# 5                   tr              tr               tr               v
# 6                   tr              tr               tr               v
# 7                   tr              tr               tr               v
# 8                   tr              tr               tr               v
# 9                   tr              tr               tr               v
# 10                  tr              tr               tr               v
# 11                  tr              tr               tr               v
# 12                  tr              tr               tr               v
# 13                  tr              tr               tr               v
# 14                  tr              tr               tr               v
# 15                  tr              tr               tr               v
# 16                  tr              tr               tr               v
# 17                  tr              tr               tr              tr
# 18                  tr              tr               tr              tr
# 19                  tr              tr               tr              tr
# 20                  tr              tr               tr              tr
# 21                  tr              tr               tr              tr
# 22                  tr              tr               tr              tr
# 23                  tr              tr               tr              tr
# 24                  tr              tr               tr              tr
# 25                  tr              tr               tr              tr
# 26                  tr              tr               tr              tr
# 27                  tr              tr               tr              tr
# 28                  tr              tr               tr              tr
# 29                  tr              tr               tr              tr
# ...                ...             ...              ...             ...
# 103666              te              tr               tr              tr
# 103667              te              tr               tr              tr
# 103668              te              tr               tr              tr
# 103669              te              tr               tr              tr
# 103670              te              tr               tr              tr
# 103671              te              tr               tr              tr
# 103672              te              tr               tr              tr
# 103673              te              tr               tr              tr
# 103674              te              tr               tr              tr
# 103675              te              tr               tr              tr
# 103676               v              tr               tr              tr
# 103677               v              tr               tr              tr
# 103678               v              tr               tr              tr
# 103679               v              tr               tr              tr
# 103680               v              tr               tr              tr
# 103681               v              tr               tr              tr
# 103682               v              tr               tr              tr
# 103683               v              tr               tr              tr
# 103684               v              tr               tr              tr
# 103685               v              tr               tr              tr
# 103686               v              tr               tr              tr
# 103687               v              tr               tr              tr
# 103688               v              tr               tr              tr
# 103689               v              tr               tr              tr
# 103690               v              tr               tr              tr
# 103691               v              tr               tr              tr
# 103692               v              tr               tr              tr
# 103693               v              tr               tr              tr
# 103694               v              tr               tr              tr
# 103695               v              tr               tr              tr
#
#        set_type_fold_8 set_type_fold_9
# 0                   tr              tr
# 1                   tr              tr
# 2                   tr              tr
# 3                   tr              tr
# 4                   tr              tr
# 5                   tr              tr
# 6                   tr              tr
# 7                   tr              tr
# 8                   tr              tr
# 9                   tr              tr
# 10                  tr              tr
# 11                  tr              tr
# 12                  tr              tr
# 13                  tr              tr
# 14                  tr              tr
# 15                  tr              tr
# 16                  tr              tr
# 17                  tr              tr
# 18                  tr              tr
# 19                  tr              tr
# 20                  tr              tr
# 21                  tr              tr
# 22                  tr              tr
# 23                  tr              tr
# 24                  tr              tr
# 25                  tr              tr
# 26                  tr              tr
# 27                  tr              tr
# 28                  tr              tr
# 29                  tr              tr
# ...                ...             ...
# 103666              tr              te
# 103667              tr              te
# 103668              tr              te
# 103669              tr              te
# 103670              tr              te
# 103671              tr              te
# 103672              tr              te
# 103673              tr              te
# 103674              tr              te
# 103675              tr              te
# 103676              tr              tr
# 103677              tr              tr
# 103678              tr              tr
# 103679              tr              tr
# 103680              tr              tr
# 103681              tr              tr
# 103682              tr              tr
# 103683              tr              tr
# 103684              tr              tr
# 103685              tr              tr
# 103686              tr              tr
# 103687              tr              tr
# 103688              tr              tr
# 103689              tr              tr
# 103690              tr              tr
# 103691              tr              tr
# 103692              tr              tr
# 103693              tr              tr
# 103694              tr              tr
# 103695              tr              tr
#
# [103696 rows x 33 columns]

# %%
'''Putting all the live samples in one folder for TF record'''
data_pd = pd.read_pickle('/home/cc/Data/Zips/silk_index_df_fixed.p')
data_pd['FilePath']= data_pd.FilePath.apply(lambda x: os.path.join('/home/cc/Data/Images/silk_static',x))
data_live = data_pd[np.logical_or(data_pd.FingerType == 'LIVE', data_pd.FingerType == 'Live')] # only live samples

# %%
data_live.shape
# Out:
# (45478, 33)

# %%
img = plt.imread(data_live.iloc[10000,3])

# %%
plt.imshow(img, cmap='gray')

# %%
images_loc = '/home/cc/Data/Allinone'
resize_df.FilePath = resize_df.FilePath.apply(lambda x: os.path.join(images_loc,x.split('/')[-1]))

# %%
resize_df.head()

# %%
def create_from_images(tfrecord_dir, image_dir, shuffle):
    print('Loading images from "%s"' % image_dir)
    image_filenames = sorted(glob.glob(os.path.join(image_dir, '*')))
    if len(image_filenames) == 0:
        error('No input images found')

    img = np.asarray(PIL.Image.open(image_filenames[0]))
    resolution = img.shape[0]
    channels = img.shape[2] if img.ndim == 3 else 1
    if img.shape[1] != resolution:
        error('Input images must have the same width and height')
    if resolution != 2 ** int(np.floor(np.log2(resolution))):
        error('Input image resolution must be a power-of-two')
    if channels not in [1, 3]:
        error('Input images must be stored as RGB or grayscale')
    
    
    with TFRecordExporter(tfrecord_dir, len(image_filenames)) as tfr:
        order = tfr.choose_shuffled_order() if shuffle else np.arange(len(image_filenames))
        for idx in range(order.size):
            img = np.asarray(PIL.Image.open(image_filenames[order[idx]]))
            if channels == 1:
                img = img[np.newaxis, :, :] # HW => CHW
            else:
                img = img.transpose([2, 0, 1]) # HWC => CHW
            tfr.add_image(img)

# %%
if not os.path.exists('/home/cc/Data/Finger'):
    os.mkdir('/home/cc/Data/Finger')

create_from_images('/home/cc/Data/Finger', images_loc , False)
