# %%
import os

import sys
'''PATH to lpips library for perceptual loss'''
new_path = '/home/cc/stylegan_K1/'
sys.path.append(new_path)

import glob
import argparse
import threading
import six.moves.queue as Queue # pylint: disable=import-error
import traceback
import numpy as np
import tensorflow as tf
import PIL.Image
import dnnlib.tflib as tflib

from training import dataset
import pandas as pd
import shutil as sh
import matplotlib.pyplot as plt

from skimage.transform import resize
from skimage import io
# Out:
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
class TFRecordExporter:
    def __init__(self, tfrecord_dir, expected_images, print_progress=True, progress_interval=10):
        self.tfrecord_dir       = tfrecord_dir
        self.tfr_prefix         = os.path.join(self.tfrecord_dir, os.path.basename(self.tfrecord_dir))
        self.expected_images    = expected_images
        self.cur_images         = 0
        self.shape              = None
        self.resolution_log2    = None
        self.tfr_writers        = []
        self.print_progress     = print_progress
        self.progress_interval  = progress_interval

        if self.print_progress:
            print('Creating dataset "%s"' % tfrecord_dir)
        if not os.path.isdir(self.tfrecord_dir):
            os.makedirs(self.tfrecord_dir)
        assert os.path.isdir(self.tfrecord_dir)

    def close(self):
        if self.print_progress:
            print('%-40s\r' % 'Flushing data...', end='', flush=True)
        for tfr_writer in self.tfr_writers:
            tfr_writer.close()
        self.tfr_writers = []
        if self.print_progress:
            print('%-40s\r' % '', end='', flush=True)
            print('Added %d images.' % self.cur_images)

    def choose_shuffled_order(self): # Note: Images and labels must be added in shuffled order.
        order = np.arange(self.expected_images)
        np.random.RandomState(123).shuffle(order)
        return order

    def add_image(self, img):
        if self.print_progress and self.cur_images % self.progress_interval == 0:
            print('%d / %d\r' % (self.cur_images, self.expected_images), end='', flush=True)
        if self.shape is None:
            self.shape = img.shape
            self.resolution_log2 = int(np.log2(self.shape[1]))
            assert self.shape[0] in [1, 3]
            assert self.shape[1] == self.shape[2]
            assert self.shape[1] == 2**self.resolution_log2
            tfr_opt = tf.python_io.TFRecordOptions(tf.python_io.TFRecordCompressionType.NONE)
            for lod in range(self.resolution_log2 - 1):
                tfr_file = self.tfr_prefix + '-r%02d.tfrecords' % (self.resolution_log2 - lod)
                self.tfr_writers.append(tf.python_io.TFRecordWriter(tfr_file, tfr_opt))
        assert img.shape == self.shape
        for lod, tfr_writer in enumerate(self.tfr_writers):
            if lod:
                img = img.astype(np.float32)
                img = (img[:, 0::2, 0::2] + img[:, 0::2, 1::2] + img[:, 1::2, 0::2] + img[:, 1::2, 1::2]) * 0.25
            quant = np.rint(img).clip(0, 255).astype(np.uint8)
            ex = tf.train.Example(features=tf.train.Features(feature={
                'shape': tf.train.Feature(int64_list=tf.train.Int64List(value=quant.shape)),
                'data': tf.train.Feature(bytes_list=tf.train.BytesList(value=[quant.tostring()]))}))
            tfr_writer.write(ex.SerializeToString())
        self.cur_images += 1

    def add_labels(self, labels):
        if self.print_progress:
            print('%-40s\r' % 'Saving labels...', end='', flush=True)
        assert labels.shape[0] == self.cur_images
        with open(self.tfr_prefix + '-rxx.labels', 'wb') as f:
            np.save(f, labels.astype(np.float32))

    def __enter__(self):
        return self

    def __exit__(self, *args):
        self.close()

# %%
'''Putting all the live samples in one folder for TF record'''
data_pd = pd.read_pickle('/home/cc/Data/Zips/silk_index_df_fixed_crop.p')
data_pd['FilePath']= data_pd.FilePath.apply(lambda x: os.path.join('/home/cc/Data/Images/silk_static',x))
data_live = data_pd[np.logical_or(data_pd.FingerType == 'LIVE', data_pd.FingerType == 'Live')] # only live samples

# %%
data_live.head()
# Out:
#    Unnamed: 0 CaptureID  Attempt CaptureID.1  \
# 0           0     ds1_1      NaN       ds1_1
# 1           1     ds1_2      NaN       ds1_2
# 2           2     ds1_3      NaN       ds1_3
# 3           3     ds1_4      NaN       ds1_4
# 4           4     ds1_5      NaN       ds1_5
#
#                                             FilePath        Finger FingerType  \
# 0  /home/cc/Data/Images/silk_static/dev_set_1/Sta...   Left Little       LIVE
# 1  /home/cc/Data/Images/silk_static/dev_set_1/Sta...   Left Little       LIVE
# 2  /home/cc/Data/Images/silk_static/dev_set_1/Sta...  Right Little       LIVE
# 3  /home/cc/Data/Images/silk_static/dev_set_1/Sta...  Right Little       LIVE
# 4  /home/cc/Data/Images/silk_static/dev_set_1/Sta...     Left Ring       LIVE
#
#                                               PathF1 PathF10  \
# 0  dev_set_1/Sequences/live/3932164900003/2000020...     NaN
# 1  dev_set_1/Sequences/live/3932164900003/2000020...     NaN
# 2  dev_set_1/Sequences/live/3932164900003/2000020...     NaN
# 3  dev_set_1/Sequences/live/3932164900003/2000020...     NaN
# 4  dev_set_1/Sequences/live/3932164900003/2000020...     NaN
#
#                                               PathF2  ... set_type_fold_2  \
# 0  dev_set_1/Sequences/live/3932164900003/2000020...  ...              tr
# 1  dev_set_1/Sequences/live/3932164900003/2000020...  ...              tr
# 2  dev_set_1/Sequences/live/3932164900003/2000020...  ...              tr
# 3  dev_set_1/Sequences/live/3932164900003/2000020...  ...              tr
# 4  dev_set_1/Sequences/live/3932164900003/2000020...  ...              tr
#
#   set_type_fold_3 set_type_fold_4 set_type_fold_5 set_type_fold_6  \
# 0              tr              tr              tr              tr
# 1              tr              tr              tr              tr
# 2              tr              tr              tr              tr
# 3              tr              tr              tr              tr
# 4              tr              tr              tr              tr
#
#   set_type_fold_7 set_type_fold_8  set_type_fold_9 x_center y_center
# 0               v              tr               tr    300.0    405.0
# 1               v              tr               tr    272.0    369.0
# 2               v              tr               tr    261.0    426.0
# 3               v              tr               tr    238.0    444.0
# 4               v              tr               tr    245.0    437.0
#
# [5 rows x 36 columns]

# %%
data_live.shape
# Out:
# (45478, 36)

# %%
images_loc = '/home/cc/Data/Allinone'
if not os.path.exists(images_loc):
    os.mkdir(images_loc)
image_rgb = np.zeros((512,512,3), dtype=np.uint8)
for i in range(len(data_live)):  
    splits = data_live.iloc[i,4].split('/')
    '''Gray to RGB for style loss we have to do this'''
    img = io.imread(data_live.iloc[i,4])
    image_resized = resize(img, (400,300), preserve_range=True, clip=True).astype(np.uint8)
    image_paded = np.pad(image_resized, ([56,56], [106,106]), 'constant', constant_values=(255, 255))
    image_rgb[:,:,0] = image_paded
    image_rgb[:,:,1] = image_paded
    image_rgb[:,:,2] = image_paded
    #image_resized = resize(image_rgb, (512,512,3), preserve_range=True, clip=True).astype(np.uint8)
    io.imsave(os.path.join(images_loc,splits[-1]), image_rgb)
    #plt.imsave(os.path.join('/home/cc/Data/Allinone',splits[-1]), image_resized)
# Out:
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181029104054617_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181029104113541_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181029104150763_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181029104301511_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181029113955281_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181029115142302_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181029133425230_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181029151134527_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181029151229316_09_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181029153523183_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181029161317201_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181029161336358_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181029161519337_10_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030093305953_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030104641199_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030111027487_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030111037971_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030111055381_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030112843189_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030112911114_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030121332197_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030121341760_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030124421932_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030133821326_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030141738374_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030141754536_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030141839372_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030145657989_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030151331396_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030151421676_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030151439336_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030151457760_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030151506262_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030151515591_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030151534156_09_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030151625700_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030153004383_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030153035459_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181030154808762_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031090422110_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031101051232_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031101059594_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031103022663_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031104212872_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031114114491_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031114133352_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031114141964_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031115239073_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031125759654_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031134817040_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031135008567_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031135025010_05_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031145339713_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031150852320_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031153850802_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031160910539_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181031160946217_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101085905782_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101085933083_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101085942396_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101092801669_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101100826352_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101100848442_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101103722206_05_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101103847416_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101105210617_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101105221147_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101105231865_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101105543937_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101113536937_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101120621404_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101120744008_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101120845707_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101121043958_10_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101122502404_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101123400743_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101124502629_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101133832650_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101133859686_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101133952478_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101134002368_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101134036190_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101134115550_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101134204005_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101134211820_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101134330680_09_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101134338574_10_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101150026566_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101150103383_05_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101150114023_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101150122525_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101150134053_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101150249918_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101150405939_10_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101154311721_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181101154320082_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102091529680_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102092808873_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102094348858_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102094357438_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102112452781_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102112510706_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102115721603_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102115729731_05_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102115743506_05_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102115750230_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102115758077_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102115817000_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102115826235_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102120128354_09_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102122002998_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102125548584_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102152418251_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102152428189_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102152504663_05_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102152701712_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102152808669_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102152851804_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102152900244_09_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102154837915_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102164913358_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181102165047975_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105084829969_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105084856349_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105090829760_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105090857497_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105091055951_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105091130600_05_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105091144796_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105095154199_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105095220314_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105113812642_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105113830769_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105113847696_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105114059878_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105114126945_09_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105114931865_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105114959087_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105115008479_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181105132746330_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106090814060_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106093341792_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106093534770_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106093642444_10_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106102437597_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106105048297_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106105149747_05_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106105256158_09_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106105307780_09_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106105316189_10_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106105324098_10_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106105606186_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106105733704_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106105744437_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106105801114_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106105807978_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106105920068_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106110041408_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106110049801_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106110059864_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106110108849_09_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106110134918_10_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106120624410_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106120946732_09_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106132139552_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106134258555_05_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106140745618_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106140901732_10_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106140951591_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106153039631_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106153049069_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106153107665_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106153217351_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106160600575_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106161743267_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181106163024652_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107114312802_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107114332974_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107115652019_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107135757395_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107135830874_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107140224178_05_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107150026707_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107153016857_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107153042192_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107160342868_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107160454585_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107160502760_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107160552417_10_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107160612073_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107161041480_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107164518331_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107164544290_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181107164610047_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108092550934_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108092559311_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108092609498_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108092812211_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108102502641_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108104257636_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108104536012_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108121549891_09_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108135839198_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108135847513_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108135856296_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108135906670_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108135915047_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108135925359_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108135950913_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108143657679_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108143735478_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108161941825_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181108162050810_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109090958316_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109091006491_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109132635652_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109132936080_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109134550159_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109134819159_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109145930296_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109150028828_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109150037019_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109150130934_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109150211432_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109154235639_04_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109154300662_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109154413485_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109154559599_08_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109155645061_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181109160232102_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112091951284_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112092053093_05_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112092108631_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112092116775_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112102131792_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112102139811_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112102148329_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112113623897_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112141442282_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112141455434_01_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112141513721_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112141530525_03_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112141604585_05_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112141615163_06_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112143032550_02_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/1_20181112143124203_07_f.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_2b670e0c62f0d754fe42fe29229790c700_Image_Trial022_Position001.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_2e5e7f12aba5fb4ed186a33740c3b72301_Image_Trial023_Position002.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_6a7511810b771af55b6cf5564d13272a01_Image_Trial011_Position001.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_7d90c7019f1f60e236a07e18c3a8784403_Image_Trial025_Position004.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_9bfb7988885e10fc4629025552a9918401_Image_Trial022_Position001.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_9fa1e9646231d8eaef6e2b619f5b5cff00_Image_Trial030_Position009.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_c0bce89f7c034f3b61797e1efa33c27e00_Image_Trial022_Position001.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_c2fa47687b644af863c6fc9504fe441801_Image_Trial022_Position001.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_5e7294779fa0fe9a9f3b56426570c5f201_Image_Trial047_Position006.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_9a93d0ef896b41f7f508c8050c608b8b01_Image_Trial047_Position002.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_efcadb0763fcd22bc9607358cfd39a1400_Image_Trial027_Position006.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_1c7c84c57cea216297110cf205af88e201_Image_Trial041_Position010.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_ab258f2f29eeb62c07a41f261f5b956800_Image_Trial032_Position001.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_ac5e9c09c162fd9eb56c09fcf8dc240b00_Image_Trial034_Position002.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_b5aa52d78b7e900fd798115559fedd5900_Image_Trial036_Position005.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_cb53efb39d6b640f066b476759d2175802_Image_Trial036_Position005.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_64097d4aefef5328c4576a62e14988d101_Image_Trial036_Position005.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_f455f0919ee544e29844f22a0532217401_Image_Trial033_Position002.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_98684d21dedb94ee92b7d8bdfc0d129b01_Image_Trial032_Position001.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_c29595780586ddf53c8bbed37c3d6fdf01_Image_Trial033_Position001.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_fe4b40fd751df7b590b057d0b68b9fd501_Image_Trial038_Position007.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_4014412a1b77fd11fdf6af04790267ea01_Image_Trial001_Position001.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_d760b6fd69cc85ea274445d3abc9702101_Image_Trial001_Position001.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_86a143623c014950a8de028beea561fc01_Image_Trial003_Position003.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_bff05d5cfc963de361d39aea07fe3c4301_Image_Trial005_Position005.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_f6b850ef1848385454a617eb83b0f98c00_Image_Trial001_Position001.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_f94155fe717e4157be517b18c1ebc32e00_Image_Trial001_Position001.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/cc/anaconda3/envs/clarkson/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/cc/Data/Allinone/SilkIDFFR_2a7ef24bd06afc78f4a879cde623b31f00_Image_Trial038_Position006.png is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
'''Cleaning the dataset - We have messed up images!!!!'''
image_filenames = sorted(glob.glob(os.path.join(images_loc, '*')))
Errors_channel = []
Errors_resulution = []
cleaned_filenames = []
for i in image_filenames:
    img = np.asarray(PIL.Image.open(i))
    if img.shape[2] !=3: 
        Errors_channel.append(i)
    elif img.shape[1] != 512:
        Errors_resulution.append(i)
    else:
        cleaned_filenames.append(i)

# %%
len(image_filenames)
# Out:
# 45478

# %%
len(cleaned_filenames)
# Out:
# 45478

# %%
Errors_channel
# Out:
# []

# %%
Errors_resulution
# Out:
# []

# %%
def create_from_images(tfrecord_dir, image_dir, shuffle):
    print('Loading images from "%s"' % image_dir)
    image_filenames = sorted(glob.glob(os.path.join(image_dir, '*')))
    if len(image_filenames) == 0:
        error('No input images found')

    img = np.asarray(PIL.Image.open(image_filenames[0]))
    resolution = img.shape[0]
    channels = img.shape[2] if img.ndim == 3 else 1
    if img.shape[1] != resolution:
        error('Input images must have the same width and height')
    if resolution != 2 ** int(np.floor(np.log2(resolution))):
        error('Input image resolution must be a power-of-two')
    if channels not in [1, 3]:
        error('Input images must be stored as RGB or grayscale')
    
    
    with TFRecordExporter(tfrecord_dir, len(image_filenames)) as tfr:
        order = tfr.choose_shuffled_order() if shuffle else np.arange(len(image_filenames))
        for idx in range(order.size):
            img = np.asarray(PIL.Image.open(image_filenames[order[idx]]))
            if channels == 1:
                img = img[np.newaxis, :, :] # HW => CHW
            else:
                img = img.transpose([2, 0, 1]) # HWC => CHW
            tfr.add_image(img)

# %%
if not os.path.exists('/home/cc/Data/Silk_512'):
    os.mkdir('/home/cc/Data/Silk_512')

create_from_images('/home/cc/Data/Silk_512', images_loc , False)
# Out:
# Loading images from "/home/cc/Data/Allinone"
# Creating dataset "/home/cc/Data/Silk_512"
# Added 45478 images.
