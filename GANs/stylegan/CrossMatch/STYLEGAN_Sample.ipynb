# %%
import os
import sys
new_path = '/home/cc/stylegan/'
sys.path.append(new_path)
import pickle
import numpy as np
import PIL.Image
import dnnlib
import dnnlib.tflib as tflib
import config
import io
import matplotlib.pyplot as plt

# %%
'''Loading Pre trained network'''
tflib.init_tf()
f = open('/home/cc/Data/karras2019stylegan-ffhq-1024x1024.pkl','rb')
_G, _D, Gs = pickle.load(f)
# Out:
# WARNING:tensorflow:From /home/cc/stylegan/dnnlib/tflib/tfutil.py:109: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From <string>:364: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
 #Gs.print_layers()

# %%
# Pick latent vector.
rnd = np.random.RandomState(5)
latents = rnd.randn(5, Gs.input_shape[1])

# Generate image.
fmt = dict(func=tflib.convert_images_to_uint8, nchw_to_nhwc=True)
images = Gs.run(latents, None, truncation_psi=0.7, randomize_noise=True, output_transform=fmt)

# %%
plt.imshow(np.squeeze(images[4,:,:,:]))
